# %%
import streamlit as st
import openpyxl
from openpyxl.drawing.image import Image
import os
import io

# Konstanta
IMAGE_FOLDER = 'uploaded_images'
TEMP_EXCEL_FILE = 'temp_data_gambar.xlsx'

# Buat folder gambar jika belum ada
if not os.path.exists(IMAGE_FOLDER):
    os.makedirs(IMAGE_FOLDER)

st.title("📸 Upload Gambar + Keterangan ➜ Simpan ke Excel (dengan Gambar)")

# 1. Upload file Excel lama (opsional)
st.subheader("1️⃣ Upload File Excel Lama (Jika Ada)")
uploaded_excel = st.file_uploader("Upload file Excel sebelumnya (optional)", type=["xlsx"])

# Simpan sementara jika user upload file Excel lama
if uploaded_excel:
    with open(TEMP_EXCEL_FILE, "wb") as f:
        f.write(uploaded_excel.getbuffer())
    st.success("File Excel lama berhasil dimuat!")
else:
    # Jika tidak upload, cek apakah sudah ada file temp sebelumnya
    if not os.path.exists(TEMP_EXCEL_FILE):
        wb = openpyxl.Workbook()
        ws = wb.active
        ws.append(['Gambar', 'Keterangan'])
        wb.save(TEMP_EXCEL_FILE)

# 2. Upload gambar + keterangan
st.subheader("2️⃣ Upload Gambar Baru dan Isi Keterangan")
uploaded_files = st.file_uploader("Upload gambar (bisa multiple)", type=["jpg", "png", "jpeg"], accept_multiple_files=True)

descriptions = []
if uploaded_files:
    for img in uploaded_files:
        desc = st.text_input(f"Keterangan untuk {img.name}", key=img.name)
        descriptions.append((img, desc))

# 3. Simpan ke Excel
if st.button("💾 Simpan ke Excel"):
    wb = openpyxl.load_workbook(TEMP_EXCEL_FILE)
    ws = wb.active
    next_row = ws.max_row + 1

    for img_file, desc in descriptions:
        if desc:
            # Simpan gambar ke folder lokal
            image_path = os.path.join(IMAGE_FOLDER, img_file.name)
            with open(image_path, "wb") as f:
                f.write(img_file.getbuffer())

            # Sisipkan gambar
            img = Image(image_path)
            img.width = 100
            img.height = 100
            ws.add_image(img, f'A{next_row}')

            # Tambahkan keterangan
            ws[f'B{next_row}'] = desc

            next_row += 1

    wb.save(TEMP_EXCEL_FILE)
    st.success("Data berhasil ditambahkan ke Excel!")

# 4. Download file Excel terbaru
st.subheader("3️⃣ Download File Excel Terbaru")
if os.path.exists(TEMP_EXCEL_FILE):
    with open(TEMP_EXCEL_FILE, "rb") as f:
        st.download_button('⬇️ Download Excel', f, file_name='data_gambar_final.xlsx')
# Out:
# 2025-04-25 13:28:18.593 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.389
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\lenovo\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-25 13:28:19.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 13:28:19.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
